# %%
import polars as pl

df = pl.read_parquet("./outputs/states.parquet")
df
# Out:
# shape: (24_821, 1_277)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestep ┆ Abkhazia_ ┆ Abkhazia_ ┆ Abkhazia_ ┆ … ┆ Åland Isl ┆ Åland Isl ┆ Åland Isl ┆ Åland Isl │
# │ ---      ┆ att_mean  ┆ att_std   ┆ def_mean  ┆   ┆ ands_att_ ┆ ands_att_ ┆ ands_def_ ┆ ands_def_ │
# │ i64      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ mean      ┆ std       ┆ mean      ┆ std       │
# │          ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0        ┆ -0.205998 ┆ 18.077673 ┆ -1.960402 ┆ … ┆ 3.069259  ┆ 16.825735 ┆ 3.038873  ┆ 16.864084 │
# │ 1        ┆ 0.640615  ┆ 0.412881  ┆ -1.117528 ┆ … ┆ 0.781125  ┆ 0.459583  ┆ -1.513958 ┆ 0.508776  │
# ...
